9.7, 12.0, 15.0, 15.9, 18.9, 10.5, 21.4, 11.9, 9.6, 17.4, 9.5, 12.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 12.9, 8.5, 14.9, 10.6, 23.2, 14.8, 9.7, 11.4, 10.7,
22.6, 21.2, 20.2, 23.7, 5.5, 13.2, 23.8, 18.4, 8.1, 24.2, 15.7, 14.0, 18.0, 9.3, 9.5, 13.4, 18.9, 22.3, 18.3, 12.4, 8.8, 11.0, 17.0, 8.7, 6.9, 14.2, 5.3, 11.0,
11.8, 12.3, 11.3, 13.6, 21.7, 15.2, 12.0, 16.0, 12.9, 16.7, 11.2, 7.3, 19.4, 22.2, 11.5, 16.9, 11.7, 15.5, 25.4, 17.2, 11.7, 23.8, 14.8, 14.7, 20.7, 19.2, 7.2, 8.7,
5.3, 19.8, 13.4, 21.8, 14.1, 15.9, 14.6, 12.6, 12.2, 9.4, 15.9, 6.6, 15.5, 7.0, 11.6, 15.2, 19.7, 10.6, 6.6, 8.8, 24.7, 9.7, 1.6, 12.7, 5.7, 19.6, 10.8, 11.6, 9.5,
20.8, 9.6, 20.7, 10.9, 19.2, 20.1, 10.4, 11.4, 10.3, 13.2, 25.4, 10.9, 10.1, 16.1, 11.6, 16.6, 19.0, 15.6, 3.2, 15.3, 10.1, 7.3, 12.9, 14.4, 13.3, 14.9, 18.0, 11.9,
11.9, 8.0, 12.2, 17.1, 15.0, 8.4, 14.5, 7.6, 11.7, 11.5, 27.0, 20.2, 11.7, 11.8, 12.6, 10.5, 12.2, 8.7, 26.2, 17.6, 22.6, 10.3, 17.3, 15.9, 6.7, 10.8, 9.9, 5.9,
19.6, 17.3, 7.6, 9.7, 12.8, 25.5, 13.4]

# %%
datos = pd.DataFrame({'tv': tv, 'radio': radio, 'periodico':periodico,
'ventas': ventas})
dt = pd.DataFrame({'tv': tv, 'radio': radio, 'periodico':periodico,
'ventas': ventas})
datos
# Out:
#         tv  radio  periodico  ventas
# 0    230.1   37.8       69.2    22.1
# 1     44.5   39.3       45.1    10.4
# 2     17.2   45.9       69.3     9.3
# 3    151.5   41.3       58.5    18.5
# 4    180.8   10.8       58.4    12.9
# ..     ...    ...        ...     ...
# 195   38.2    3.7       13.8     7.6
# 196   94.2    4.9        8.1     9.7
# 197  177.0    9.3        6.4    12.8
# 198  283.6   42.0       66.2    25.5
# 199  232.1    8.6        8.7    13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# Para esto obtenga lo siguiente:
# 1. 1. Obtenga la distribución de cada una de las variables

# %%
datos.describe()
# Out:
#                tv       radio   periodico      ventas
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = datos["tv"]
y = datos["ventas"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('Grafico de ventas vs tv')
plt.xlabel('x: Cantidad de anuncios de tv')
plt.ylabel('y: Igresos conseguidos por ventas')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = datos["radio"]
y = datos["ventas"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('Grafico de ventas vs radio')
plt.xlabel('x: Cantidad de anuncios de radio')
plt.ylabel('y: Igresos conseguidos por ventas')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = datos["periodico"]
y = datos["ventas"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('Grafico de ventas vs periodico')
plt.xlabel('x: Cantidad de anuncios de periodico')
plt.ylabel('y: Igresos conseguidos por ventas')
plt.show()

# %% [markdown]
# 2. Separe sus datos en 70/30

# %%
msk = np.random.rand(len(datos)) < 0.7
train = dt[msk]
test = dt[~msk]

# %% [markdown]
# 3. Obtenga su modelo de Regresión lineal

# %%
import sklearn as skl
from sklearn import linear_model
# Modelo de entrenamiento
lm = linear_model.LinearRegression()
import pandas as pd
import statsmodels.api as sm 
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import random

# %%
x1 = dt["tv"]
x2 = dt["radio"] 
x3 = dt["periodico"] 
y = dt["ventas"] 

mod = smf.ols('y ~ x1 + x2 + x3', data=dt).fit() 
# Ajusta el modelo usando el registro natural de uno de los regresores
print(mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sat, 10 Jun 2023   Prob (F-statistic):           1.58e-96
# Time:                        19:26:58   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# x1             0.0458      0.001     32.809      0.000       0.043       0.049
# x2             0.1885      0.009     21.893      0.000       0.172       0.206
# x3            -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# 4. Entregue la recta matemática de regresión con las estimaciones obtenidas

# %%
mod.params
# Out:
# Intercept    2.938889
# x1           0.045765
# x2           0.188530
# x3          -0.001037
# dtype: float64

# %%
# The coefficients
print ('La recta es: y = x1 * 0.0458 + x2 * 0.1885 + x3 * -0.0010 + 2.9389')
# Out:
# La recta es: y = x1 * 0.0458 + x2 * 0.1885 + x3 * -0.0010 + 2.9389

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
X = np.asanyarray(train[['tv','radio','periodico']])
y = np.asanyarray(train[['ventas']])
regr.fit (X, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[ 0.04443114  0.1996788  -0.00269764]]

# %% [markdown]
# 5. Realice un diagnóstico de los residuos del modelo.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y,
                                        train_size   = 0.8,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %%
y_train = y_train.flatten()
prediccion_train = modelo.predict(exog = X_train)
residuos_train   = prediccion_train - y_train

# %%
# Gráficos
import seaborn as sns
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(9, 8))

axes[0, 0].scatter(y_train, prediccion_train, edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 0].plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()],
                'k--', color = 'black', lw=2)
axes[0, 0].set_title('Valor predicho vs valor real', fontsize = 10, fontweight = "bold")
axes[0, 0].set_xlabel('Real')
axes[0, 0].set_ylabel('Predicción')
axes[0, 0].tick_params(labelsize = 7)

axes[0, 1].scatter(list(range(len(y_train))), residuos_train,
                   edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 1].axhline(y = 0, linestyle = '--', color = 'black', lw=2)
axes[0, 1].set_title('Residuos del modelo', fontsize = 10, fontweight = "bold")
axes[0, 1].set_xlabel('id')
axes[0, 1].set_ylabel('Residuo')
axes[0, 1].tick_params(labelsize = 7)

sns.histplot(
    data    = residuos_train,
    stat    = "density",
    kde     = True,
    line_kws= {'linewidth': 1},
    color   = "firebrick",
    alpha   = 0.3,
    ax      = axes[1, 0]
)

axes[1, 0].set_title('Distribución residuos del modelo', fontsize = 10,
                     fontweight = "bold")
axes[1, 0].set_xlabel("Residuo")
axes[1, 0].tick_params(labelsize = 7)


sm.qqplot(
    residuos_train,
    fit   = True,
    line  = 'q',
    ax    = axes[1, 1], 
    color = 'firebrick',
    alpha = 0.4,
    lw    = 2
)
axes[1, 1].set_title('Q-Q residuos del modelo', fontsize = 10, fontweight = "bold")
axes[1, 1].tick_params(labelsize = 7)

axes[2, 0].scatter(prediccion_train, residuos_train,
                   edgecolors=(0, 0, 0), alpha = 0.4)
axes[2, 0].axhline(y = 0, linestyle = '--', color = 'black', lw=2)
axes[2, 0].set_title('Residuos del modelo vs predicción', fontsize = 10, fontweight = "bold")
axes[2, 0].set_xlabel('Predicción')
axes[2, 0].set_ylabel('Residuo')
axes[2, 0].tick_params(labelsize = 7)

# Se eliminan los axes vacíos
fig.delaxes(axes[2,1])

fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Diagnóstico residuos', fontsize = 12, fontweight = "bold");
# Out:
# C:\Users\Erik\AppData\Local\Temp\ipykernel_19808\366321814.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[0, 0].plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()],
# C:\ProgramData\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:1045: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# 6. Realice el test de normalidad

# %%
from scipy import stats
shapiro_test = stats.shapiro(residuos_train)
shapiro_test
# Out:
# ShapiroResult(statistic=0.9628909230232239, pvalue=0.002555695129558444)

# %%
k2, p_value = stats.normaltest(residuos_train)
print(f"Estadítico= {k2}, p-value = {p_value}")
# Out:
# Estadítico= 8.365133677088417, p-value = 0.015259289123073854

# %% [markdown]
# 7. Obtenga las predicciones del modelo

# %%
predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
predicciones
# Out:
#           mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0    13.429711  0.249448      12.935509      13.923913     10.339470
# 1    17.474773  0.327776      16.825390      18.124156     14.355950
# 2    21.693300  0.306337      21.086392      22.300209     18.583044
# 3    12.100781  0.199426      11.705682      12.495880      9.024832
# 4     3.365125  0.347927       2.675818       4.054432      0.237746
# ..         ...       ...            ...            ...           ...
# 112   9.114541  0.228322       8.662195       9.566887      6.030716
# 113  13.902808  0.232821      13.441549      14.364068     10.817664
# 114  14.008970  0.216753      13.579544      14.438397     10.928424
# 115  12.103954  0.265111      11.578721      12.629187      9.008598
# 116   7.762476  0.286040       7.195780       8.329172      4.659815
#
#      obs_ci_upper
# 0       16.519953
# 1       20.593596
# 2       24.803557
# 3       15.176730
# 4        6.492504
# ..            ...
# 112     12.198366
# 113     16.987953
# 114     17.089516
# 115     15.199310
# 116     10.865136
#
# [117 rows x 6 columns]

# %% [markdown]
# 8. Entregue el error del test

# %%
from sklearn.metrics import mean_squared_error
X_test = sm.add_constant(X_test, prepend=True)
predicciones = modelo.predict(exog = X_test)
rmse = mean_squared_error(
        y_true  = y_test,
        y_pred  = predicciones,
        squared = False
       )
print("")
print(f"El error (rmse) de test es: {rmse}")
# Out:
# El error (rmse) de test es: 1.605084169827312
