# %% [markdown]
# Usted cuenta con 3 archivos csv con los siguientes nombres:

# %% [markdown]
# 1. Cargue los tres datasets usando pandas.

# %%
#Importar
import pandas as pd
#Dividir en punto y coma ademas de considerar el punto como decimal. Y mostar. 
df1 = pd.read_csv("state-abbrevs.csv", sep=';')
df1.head(10)
# Out:
#                   state abbreviation
# 0               Alabama           AL
# 1                Alaska           AK
# 2               Arizona           AZ
# 3              Arkansas           AR
# 4            California           CA
# 5              Colorado           CO
# 6           Connecticut           CT
# 7              Delaware           DE
# 8  District of Columbia           DC
# 9               Florida           FL

# %%
#Dividir en punto y coma ademas de considerar el punto como decimal. Y mostar. 
df2 = pd.read_csv("state-area.csv", sep=';')
df2.head(10)
# Out:
#          state  area (sq. mi)
# 0      Alabama          52423
# 1       Alaska         656425
# 2      Arizona         114006
# 3     Arkansas          53182
# 4   California         163707
# 5     Colorado         104100
# 6  Connecticut           5544
# 7     Delaware           1954
# 8      Florida          65758
# 9      Georgia          59441

# %%
#Dividir en punto y coma ademas de considerar el punto como decimal. Y mostar. 
df3 = pd.read_csv("state-population.csv", sep=';')
df3
# Out:
#      abbreviation     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %% [markdown]
# 2. Revise los datos cargados y realice las modificaciones necesarias para empezar a trabajar

# %%
df_1 = pd.merge(df1, df2)
df_2 = pd.merge(df_1, df3)
df_2
# Out:
#         state abbreviation  area (sq. mi)     ages  year  population
# 0     Alabama           AL          52423  under18  2012   1117489.0
# 1     Alabama           AL          52423    total  2012   4817528.0
# 2     Alabama           AL          52423  under18  2010   1130966.0
# 3     Alabama           AL          52423    total  2010   4785570.0
# 4     Alabama           AL          52423  under18  2011   1125763.0
# ...       ...          ...            ...      ...   ...         ...
# 2443  Wyoming           WY          97818  under18  1993    137458.0
# 2444  Wyoming           WY          97818    total  1991    459260.0
# 2445  Wyoming           WY          97818  under18  1991    136720.0
# 2446  Wyoming           WY          97818  under18  1990    136078.0
# 2447  Wyoming           WY          97818    total  1990    453690.0
#
# [2448 rows x 6 columns]

# %% [markdown]
# 3. Elimine las columnas que no aportan información

# %%
df_3 = df_2[['state', 'ages', 'population' ]]
df_3
# Out:
#         state     ages  population
# 0     Alabama  under18   1117489.0
# 1     Alabama    total   4817528.0
# 2     Alabama  under18   1130966.0
# 3     Alabama    total   4785570.0
# 4     Alabama  under18   1125763.0
# ...       ...      ...         ...
# 2443  Wyoming  under18    137458.0
# 2444  Wyoming    total    459260.0
# 2445  Wyoming  under18    136720.0
# 2446  Wyoming  under18    136078.0
# 2447  Wyoming    total    453690.0
#
# [2448 rows x 3 columns]

# %% [markdown]
# 4. Agrupe por state/region y ages, para luego agregar usando promedio, mínimo, máximo y contar

# %%
#Mostrar el Promedio
print("Promedio:")
print(df_3.groupby(['state','ages'])['population'].mean().unstack())
# Out:
# Promedio:
# ages                         total       under18
# state
# Alabama               4.484528e+06  1.111197e+06
# Alaska                6.462048e+05  1.866730e+05
# Arizona               5.294600e+06  1.380554e+06
# Arkansas              2.693178e+06  6.801024e+05
# California            3.433414e+07  9.084020e+06
# Colorado              4.359393e+06  1.096213e+06
# Connecticut           3.440903e+06  8.159816e+05
# Delaware              8.029724e+05  1.928678e+05
# District of Columbia  5.870693e+05  1.122373e+05
# Florida               1.649654e+07  3.669713e+06
# Georgia               8.376483e+06  2.194359e+06
# Hawaii                1.255944e+06  3.003040e+05
# Idaho                 1.336846e+06  3.784035e+05
# Illinois              1.237080e+07  3.144609e+06
# Indiana               6.122213e+06  1.554547e+06
# Iowa                  2.937936e+06  7.256411e+05
# Kansas                2.701945e+06  7.051930e+05
# Kentucky              4.076325e+06  9.964704e+05
# ...

# %%
print("Minimo:")
print(df_3.groupby(['state','ages'])['population'].min().unstack())
# Out:
# Minimo:
# ages                       total    under18
# state
# Alabama                4050055.0  1050041.0
# Alaska                  553290.0   177502.0
# Arizona                3684097.0  1006040.0
# Arkansas               2356586.0   620933.0
# California            29959515.0  7980501.0
# Colorado               3307618.0   881640.0
# Connecticut            3291967.0   752666.0
# Delaware                669567.0   165628.0
# District of Columbia    565232.0   101309.0
# Florida               13033307.0  2988807.0
# Georgia                6512602.0  1747363.0
# Hawaii                 1113491.0   279983.0
# Idaho                  1012384.0   313373.0
# Illinois              11453316.0  2940837.0
# Indiana                5557798.0  1437209.0
# Iowa                   2781018.0   718488.0
# Kansas                 2481349.0   662641.0
# Kentucky               3694048.0   945951.0
# Louisiana              4221532.0  1078779.0
# Maine                  1231719.0   261276.0
# ...

# %%
print("Maximo:")
print(df_3.groupby(['state','ages'])['population'].max().unstack())
# Out:
# Maximo:
# ages                       total    under18
# state
# Alabama                4833722.0  1134927.0
# Alaska                  735132.0   192636.0
# Arizona                6626624.0  1628651.0
# Arkansas               2959373.0   711947.0
# California            38332521.0  9418497.0
# Colorado               5268367.0  1237932.0
# Connecticut            3596080.0   851115.0
# Delaware                925749.0   206213.0
# District of Columbia    646449.0   123620.0
# Florida               19552860.0  4031098.0
# Georgia                9992167.0  2490884.0
# Hawaii                 1404054.0   311213.0
# Idaho                  1612136.0   428961.0
# Illinois              12882135.0  3244944.0
# Indiana                6570902.0  1611494.0
# Iowa                   3090416.0   733337.0
# Kansas                 2893957.0   727729.0
# Kentucky               4395295.0  1023679.0
# Louisiana              4625470.0  1250112.0
# Maine                  1330509.0   311570.0
# ...

# %%
print("Contar:")
print(df_3.groupby(['state','ages'])['population'].count().unstack())
# Out:
# Contar:
# ages                  total  under18
# state
# Alabama                  24       24
# Alaska                   24       24
# Arizona                  24       24
# Arkansas                 24       24
# California               24       24
# Colorado                 24       24
# Connecticut              24       24
# Delaware                 24       24
# District of Columbia     24       24
# Florida                  24       24
# Georgia                  24       24
# Hawaii                   24       24
# Idaho                    24       24
# Illinois                 24       24
# Indiana                  24       24
# Iowa                     24       24
# Kansas                   24       24
# Kentucky                 24       24
# Louisiana                24       24
# Maine                    24       24
# Maryland                 24       24
# Massachusetts            24       24
# Michigan                 24       24
# Minnesota                24       24
# ...

# %% [markdown]
# 5. Forme un nuevo dataset llamado df que tenga la información de los 3 sets importados. Use las llaves necesarias.

# %%
df_1 = pd.merge(df1, df2)
df = pd.merge(df_1, df3)
df
# Out:
#         state abbreviation  area (sq. mi)  population     ages  year
# 0     Alabama           AL          52423   1117489.0  under18  2012
# 1     Alabama           AL          52423   4817528.0    total  2012
# 2     Alabama           AL          52423   1130966.0  under18  2010
# 3     Alabama           AL          52423   4785570.0    total  2010
# 4     Alabama           AL          52423   1125763.0  under18  2011
# ...       ...          ...            ...         ...      ...   ...
# 2443  Wyoming           WY          97818    137458.0  under18  1993
# 2444  Wyoming           WY          97818    459260.0    total  1991
# 2445  Wyoming           WY          97818    136720.0  under18  1991
# 2446  Wyoming           WY          97818    136078.0  under18  1990
# 2447  Wyoming           WY          97818    453690.0    total  1990
#
# [2448 rows x 6 columns]

# %% [markdown]
# 6. Calcule la población por área para cada estado. Para esto agrupe por state/region y calcule el promedio de la población. Guarde dicha información en un data frame con las columnas 'state' y 'pop/area' (hint: puede extraer los valores de un objeto groupby, finalizando su sentencia con .values, o extraer sus etiquetas con .index)

# %%
df_7 = pd.DataFrame(round(a,2), columns=["pop/area"])

df_7

#Mostrar el Promedio
print("Población por área para cada estado:")
a = df.groupby('state')['population'].mean() / df.groupby('state')['area (sq. mi)'].mean()

df_7 = pd.DataFrame(round(a, 2),  
                columns=["Odd Numbers"])

print(df_7)

# %%
import pandas as pd
datos = {'state': df['state'],
        'population': df['population'],
        'area (sq. mi)': df['area (sq. mi)'],
        'pop/area': round(df['population']/df['area (sq. mi)'], 2)
        }
df_final = pd.DataFrame(datos)
print(df_final)
# Out:
#         state  population  area (sq. mi)  pop/area
# 0     Alabama   1117489.0          52423     21.32
# 1     Alabama   4817528.0          52423     91.90
# 2     Alabama   1130966.0          52423     21.57
# 3     Alabama   4785570.0          52423     91.29
# 4     Alabama   1125763.0          52423     21.47
# ...       ...         ...            ...       ...
# 2443  Wyoming    137458.0          97818      1.41
# 2444  Wyoming    459260.0          97818      4.70
# 2445  Wyoming    136720.0          97818      1.40
# 2446  Wyoming    136078.0          97818      1.39
# 2447  Wyoming    453690.0          97818      4.64
#
# [2448 rows x 4 columns]

# %%
promedios=df_final.groupby('state')[['area (sq. mi)','population','pop/area']].mean()
promedios
# Out:
#                       area (sq. mi)    population     pop/area
# state
# Alabama                     52423.0  2.797862e+06    53.370833
# Alaska                     656425.0  4.164389e+05     0.634583
# Arizona                    114006.0  3.337577e+06    29.275000
# Arkansas                    53182.0  1.686640e+06    31.713958
# California                 163707.0  2.170908e+07   132.608750
# Colorado                   104100.0  2.727803e+06    26.203333
# Connecticut                  5544.0  2.128442e+06   383.918125
# Delaware                     1954.0  4.979201e+05   254.820625
# District of Columbia           68.0  3.496533e+05  5141.960000
# Florida                     65758.0  1.008313e+07   153.337292
# Georgia                     59441.0  5.285421e+06    88.918958
# Hawaii                      10932.0  7.781240e+05    71.178542
# Idaho                       83574.0  8.576250e+05    10.261042
# Illinois                    57918.0  7.757703e+06   133.943125
# ...

# %% [markdown]
# 7. Finalmente, cree un dataframe que posea: El estado, el área, la población, la población por área y como índice la abreviación del nombre del estado.

# %%
datos1 = {'abbreviation': df['abbreviation'],
        'state': df['state'],
        'population': df['population'],
        'area (sq. mi)': df['area (sq. mi)'],
        'pop/area': round(df['population']/df['area (sq. mi)'], 2)
        }
df_final1 = pd.DataFrame(datos1)

promedios1=df_final1.groupby('abbreviation')[['area (sq. mi)','state','population','pop/area']].mean()
promedios1
# Out:
# C:\Users\Erik\AppData\Local\Temp\ipykernel_8396\19054588.py:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   promedios1=df_final1.groupby('abbreviation')[['area (sq. mi)','state','population','pop/area']].mean()
#               area (sq. mi)    population     pop/area
# abbreviation
# AK                 656425.0  4.164389e+05     0.634583
# AL                  52423.0  2.797862e+06    53.370833
# AR                  53182.0  1.686640e+06    31.713958
# AZ                 114006.0  3.337577e+06    29.275000
# CA                 163707.0  2.170908e+07   132.608750
# CO                 104100.0  2.727803e+06    26.203333
# CT                   5544.0  2.128442e+06   383.918125
# DC                     68.0  3.496533e+05  5141.960000
# DE                   1954.0  4.979201e+05   254.820625
# ...
