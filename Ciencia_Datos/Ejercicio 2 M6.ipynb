# %% [markdown]
# Clasificación de Clientes según su personalidad.

# %% [markdown]
# Luego de haber cerrado su cápsula de aprendizaje de clasificación, se le ha
# determinado que averigue los intereses que pueden tener los clientes de la
# empresa KEPPLER, esto es necesario, para que se entregue la información al
# departamento de marketing y puedan realizar campañas para fidelizar a sus
# clientes.

# %% [markdown]
# En el archivo clientes.cvs encontrará el registro de cada uno de ellos, además el archivo contiene 9 categorías -actividades laborales- que son:

# %% [markdown]
# ● Actor/actriz
# ● Cantante
# ● Modelo
# ● Tv, series
# ● Radio
# ● Tecnología
# ● Deportes
# ● Politica
# ● Escritor

# %% [markdown]
# 1. Realice un resumen estadístico de sus datos.

# %%
import pandas as pd
#Dividir en punto y coma ademas de considerar el punto como decimal. Y mostar. 
df = pd.read_csv("CD - M6 AE2 clientes.csv", sep=';')
display(df)
# Out:
#              usuario        op        co        ex        ag        ne  \
# 0       3gerardpique  34297953  28148819  41948819  29370315   9841575
# 1    aguerosergiokun  44986842  20525865  37938947  24279098  10362406
# 2     albertochicote  41733854  13745417  38999896  34645521   8836979
# 3      AlejandroSanz  40377154  15377462  52337538  31082154   5032231
# 4     alfredocasero1  36664677  19642258  48530806  31138871   7305968
# ..               ...       ...       ...       ...       ...       ...
# 135       XabiAlonso  35569389  22133740  38904885  31624351  12201221
# 136    XaviRodriguez  31960417  15416979  48533125  40096458  11764583
# 137        xoellopez  71696129  12489274  27571210  19093548   3241935
# 138         ZacEfron  51537405  26009695  36465344  23008168   7284962
# 139   _josecoronado_  36258913  18769348  45225652  39427283   9252065
#
#      wordcount  categoria
# 0       370945          7
# 1       787970          7
# 2       492604          4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   usuario    140 non-null    object
#  1   op         140 non-null    int64
#  2   co         140 non-null    int64
#  3   ex         140 non-null    int64
#  4   ag         140 non-null    int64
#  5   ne         140 non-null    int64
#  6   wordcount  140 non-null    int64
#  7   categoria  140 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 8.9+ KB

# %%
df.describe()
# Out:
#                  op            co            ex            ag            ne  \
# count  1.400000e+02  1.400000e+02  1.400000e+02  1.400000e+02  1.400000e+02
# mean   4.441459e+07  2.297714e+07  4.076443e+07  2.291853e+07  8.000098e+06
# std    8.425723e+06  5.816851e+06  7.185246e+06  7.657122e+06  3.039248e+06
# min    3.002046e+07  7.852756e+06  1.869354e+07  9.305985e+06  1.030213e+06
# 25%    3.820648e+07  1.974030e+07  3.609572e+07  1.705099e+07  6.086144e+06
# 50%    4.450709e+07  2.246672e+07  4.145749e+07  2.138455e+07  7.839722e+06
# 75%    4.936592e+07  2.609161e+07  4.519777e+07  2.867887e+07  9.758189e+06
# max    7.169613e+07  4.963786e+07  5.982484e+07  4.058316e+07  2.397846e+07
#
#           wordcount   categoria
# count  1.400000e+02  140.000000
# mean   9.871548e+05    4.050000
# std    4.471407e+05    2.658839
# min    5.020800e+04    1.000000
# 25%    6.621848e+05    2.000000
# 50%    9.471140e+05    3.500000
# 75%    1.197079e+06    7.000000
# ...

# %%
a = df.groupby('categoria').size()
a
# Out:
# categoria
# 1    27
# 2    34
# 3     9
# 4    19
# 5     4
# 6     8
# 7    17
# 8    16
# 9     6
# dtype: int64

# %% [markdown]
# Respecto a los datos analizados, se puede identificar que existen 7 tabulaciones en columna. Considerando que las primeras seis tienen datos dispersos. Ahora respecto a la septima, esta corresponde a una clasificacion de categoria de actividades del usuario, destacandose que la mayor cantidad de datos estan agrupados para los cantantes, actor/actriz y tv.

# %% [markdown]
# 2. Entregue gráficos que acompañen los hallazgos encontrados en el punto 1.

# %%
import matplotlib.pyplot as plt
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = df["op"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('op')
plt.show()
#ex	ag	ne	wordcount	categoria

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = pd.DataFrame(df['categoria'])
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('categoria')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = df["wordcount"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('wordcount')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = df["ne"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('ne')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = df["ag"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('ag')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = df["ex"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('ex')
plt.show()

# %%
#Importar librerias
fig,ax = plt.subplots()
#cantidad media de habitaciones
x = df["co"]
ax.hist(x, color = "tab:blue")
#Titulos
plt.title('co')
plt.show()

# %% [markdown]
# 3. Encuentre una relación o grafique las variables: op, ex y ag, además de las categorías.

# %%
import numpy as np
X = np.array(df[["op","ex","ag"]])
x = np.array(df['op'])
y = np.array(df['ex'])
z = np.array(df['ag'])
d = np.array(df['categoria'])
d
# Out:
# array([7, 7, 4, 2, 4, 7, 7, 5, 7, 7, 3, 1, 1, 2, 8, 3, 4, 6, 2, 4, 2, 3,
#        3, 7, 2, 4, 8, 1, 4, 3, 8, 1, 2, 7, 4, 5, 1, 2, 2, 1, 6, 2, 6, 1,
#        1, 2, 6, 3, 1, 7, 2, 8, 6, 2, 8, 2, 1, 3, 8, 2, 8, 4, 2, 1, 8, 9,
#        1, 1, 2, 4, 6, 8, 8, 4, 9, 2, 8, 4, 4, 9, 5, 2, 4, 1, 2, 7, 2, 3,
#        2, 1, 2, 7, 2, 2, 1, 7, 7, 2, 4, 6, 1, 1, 1, 4, 2, 4, 2, 8, 7, 5,
#        9, 9, 8, 9, 7, 1, 8, 2, 4, 8, 8, 2, 2, 1, 2, 1, 6, 2, 4, 2, 1, 1,
#        1, 7, 3, 7, 4, 2, 1, 1], dtype=int64)

# %%
# importamos las librerias necesarias
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# Creamos la figura
fig = plt.figure()
# Creamos el plano 3D
ax1 = fig.add_subplot(111, projection='3d')

# Agregamos los puntos en el plano 3D
ax1.scatter(x, y, z, c=np.array(df['categoria']) , marker='o')

# Mostramos el gráfico
plt.show()

# %% [markdown]
# 4. Determine cuántos k o clúster son adecuados para esta consulta.

# %%
import warnings
warnings.filterwarnings("ignore")

Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %% [markdown]
# Entre 5 y 7,5 es un buen numero K para el modelo.

# %% [markdown]
# 5. Realice un modelo de k means con los cluster definidos en el punto 4.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

kmeans = KMeans(n_clusters=6).fit(X)
centroids = kmeans.cluster_centers_

print(centroids)
# Out:
# [[50577509.82051282 40742713.25641026 17364411.87179487]
#  [35763433.06666667 52588895.66666666 31644574.73333333]
#  [43424893.42105263 32204191.21052632 19276344.21052631]
#  [59427303.35714286 30789015.92857143 16134491.92857143]
#  [40208605.45454546 43622789.63636363 23102965.87878788]
#  [36256457.2        42337137.3        35109096.34999999]]

# %% [markdown]
# 6. Entregue una representación gráfica de los cluster.

# %%
# importamos las librerias necesarias
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# Creamos la figura
fig = plt.figure()
# Creamos el plano 3D
ax1 = fig.add_subplot(111, projection='3d')

# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

x1 = centroids[:, 0]
x2 = centroids[:, 1]
x3 = centroids[:, 2]

# Agregamos los puntos en el plano 3D
ax1.scatter(x, y, z, c=np.array(df['categoria']) , marker='o')
ax1.scatter(x1, x2, x3,marker='x', s=1000)

# Mostramos el gráfico
plt.show()

# %% [markdown]
# 7. A qué conclusión llega y cuál es su recomendación como experto.

# %%
b1 =  pd.DataFrame()
b1['cantidad']=copy.groupby('label').size()
b1['cantidad']
# Out:
# label
# 0    34
# 1    40
# 2    34
# 3    18
# 4    14
# Name: cantidad, dtype: int64

# %%
group_referrer_index = copy['label'] ==0
group_referrals = copy[group_referrer_index]
 
c1 =  pd.DataFrame()
c1['cantidad']=group_referrals.groupby('categoria').size()
c1
# Out:
#            cantidad
# categoria
# 1                 3
# 2                 4
# 4                12
# 5                 3
# 6                 1
# 7                 5
# 8                 3
# 9                 3

# %% [markdown]
# Segun lso resultados, se puede colcuir que los grupos esta diferenciados predominando la actividad de correspondiente a la tv. Ahora respecto a las relaciones, se puede concluir que no necesariemnete hay relacion en los grupos segun sus actividades.
