# %% [markdown]
# Para este ejercicio, primero debe obtener los datos de gapminder de la URL de carpintería de software y cargarlos como marco de datos de pandas. Los datos de gapminder tienen información sobre la vida útil, la población y el pib de los países durante varios años.

# %% [markdown]
# Para eso use el siguiente código:

# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

# %%
gapminder_csv_url = 'http://bit.ly/2cLzoxH'
gapminder = pd.read_csv(gapminder_csv_url)
print(gapminder.head(3))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710

# %% [markdown]
# A partir de esto, realice lo siguiente:
# 1. Realice un resumen estadístico de sus datos.

# %%
gapminder.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# 2. Agrupe por la variable “año”. Comente respecto al resultado al usar groupby.

# %%
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year", "continent", "country"], as_index=True).mean()
gapminder_grouped
# Out:
#                                       pop  lifeExp     gdpPercap
# year continent country
# 1952 Africa    Algeria          9279525.0   43.077   2449.008185
#                Angola           4232095.0   30.015   3520.610273
#                Benin            1738315.0   38.223   1062.752200
#                Botswana          442308.0   47.622    851.241141
#                Burkina Faso     4469979.0   31.975    543.255241
# ...                                   ...      ...           ...
# 2007 Europe    Switzerland      7554661.0   81.701  37506.419070
#                Turkey          71158647.0   71.777   8458.276384
#                United Kingdom  60776238.0   79.425  33203.261280
#      Oceania   Australia       20434176.0   81.235  34435.367440
#                New Zealand      4115771.0   80.204  25185.009110
#
# [1704 rows x 3 columns]

# %% [markdown]
# 3. Ahora obtenga la suma (la cantidad), la media y la mediana para cada grupo, es decir, por año.

# %%
#Suma
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year", "continent", "country"], as_index=True).sum()
gapminder_grouped
# Out:
#                                       pop  lifeExp     gdpPercap
# year continent country
# 1952 Africa    Algeria          9279525.0   43.077   2449.008185
#                Angola           4232095.0   30.015   3520.610273
#                Benin            1738315.0   38.223   1062.752200
#                Botswana          442308.0   47.622    851.241141
#                Burkina Faso     4469979.0   31.975    543.255241
# ...                                   ...      ...           ...
# 2007 Europe    Switzerland      7554661.0   81.701  37506.419070
#                Turkey          71158647.0   71.777   8458.276384
#                United Kingdom  60776238.0   79.425  33203.261280
#      Oceania   Australia       20434176.0   81.235  34435.367440
#                New Zealand      4115771.0   80.204  25185.009110
#
# [1704 rows x 3 columns]

# %%
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year"], as_index=True).sum()
gapminder_grouped
# Out:
#                pop     lifeExp     gdpPercap
# year
# 1952  2.406957e+09  6966.18200  5.289892e+05
# 1957  2.664405e+09  7314.05096  6.105160e+05
# 1962  2.899783e+09  7612.51336  6.710654e+05
# 1967  3.217478e+09  7906.31712  7.786787e+05
# 1972  3.576977e+09  8185.92888  9.613518e+05
# 1977  3.930046e+09  8458.96236  1.038470e+06
# 1982  4.289437e+09  8737.71400  1.067684e+06
# 1987  4.691477e+09  8976.19100  1.121931e+06
# 1992  5.110710e+09  9110.76800  1.158522e+06
# 1997  5.515204e+09  9232.08400  1.290805e+06
# 2002  5.886978e+09  9328.67900  1.408334e+06
# 2007  6.251013e+09  9515.05400  1.658570e+06

# %%
#Mediana
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year", "continent", "country"], as_index=True).median()
gapminder_grouped
# Out:
#                                       pop  lifeExp     gdpPercap
# year continent country
# 1952 Africa    Algeria          9279525.0   43.077   2449.008185
#                Angola           4232095.0   30.015   3520.610273
#                Benin            1738315.0   38.223   1062.752200
#                Botswana          442308.0   47.622    851.241141
#                Burkina Faso     4469979.0   31.975    543.255241
# ...                                   ...      ...           ...
# 2007 Europe    Switzerland      7554661.0   81.701  37506.419070
#                Turkey          71158647.0   71.777   8458.276384
#                United Kingdom  60776238.0   79.425  33203.261280
#      Oceania   Australia       20434176.0   81.235  34435.367440
#                New Zealand      4115771.0   80.204  25185.009110
#
# [1704 rows x 3 columns]

# %%
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year"], as_index=True).median()
gapminder_grouped
# Out:
#              pop  lifeExp    gdpPercap
# year
# 1952   3943953.0  45.1355  1968.528344
# 1957   4282942.0  48.3605  2173.220291
# 1962   4686039.5  50.8810  2335.439533
# 1967   5170175.5  53.8250  2678.334740
# 1972   5877996.5  56.5300  3339.129407
# 1977   6404036.5  59.6720  3798.609244
# 1982   7007320.0  62.4415  4216.228428
# 1987   7774861.5  65.8340  4280.300366
# 1992   8688686.5  67.7030  4386.085502
# 1997   9735063.5  69.3940  4781.825478
# 2002  10372918.5  70.8255  5319.804524
# 2007  10517531.0  71.9355  6124.371108

# %%
#Media
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year", "continent", "country"], as_index=True).mean()
gapminder_grouped
# Out:
#                                       pop  lifeExp     gdpPercap
# year continent country
# 1952 Africa    Algeria          9279525.0   43.077   2449.008185
#                Angola           4232095.0   30.015   3520.610273
#                Benin            1738315.0   38.223   1062.752200
#                Botswana          442308.0   47.622    851.241141
#                Burkina Faso     4469979.0   31.975    543.255241
# ...                                   ...      ...           ...
# 2007 Europe    Switzerland      7554661.0   81.701  37506.419070
#                Turkey          71158647.0   71.777   8458.276384
#                United Kingdom  60776238.0   79.425  33203.261280
#      Oceania   Australia       20434176.0   81.235  34435.367440
#                New Zealand      4115771.0   80.204  25185.009110
#
# [1704 rows x 3 columns]

# %%
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year"], as_index=True).mean()
gapminder_grouped
# Out:
#                pop    lifeExp     gdpPercap
# year
# 1952  1.695040e+07  49.057620   3725.276046
# 1957  1.876341e+07  51.507401   4299.408345
# 1962  2.042101e+07  53.609249   4725.812342
# 1967  2.265830e+07  55.678290   5483.653047
# 1972  2.518998e+07  57.647386   6770.082815
# 1977  2.767638e+07  59.570157   7313.166421
# 1982  3.020730e+07  61.533197   7518.901673
# 1987  3.303857e+07  63.212613   7900.920218
# 1992  3.599092e+07  64.160338   8158.608521
# 1997  3.883947e+07  65.014676   9090.175363
# 2002  4.145759e+07  65.694923   9917.848365
# 2007  4.402122e+07  67.007423  11680.071820

# %%
gapminder.groupby( 'year').agg(['sum', 'mean','median'])
# Out:
#                pop                               lifeExp                      \
#                sum          mean      median         sum       mean   median
# year
# 1952  2.406957e+09  1.695040e+07   3943953.0  6966.18200  49.057620  45.1355
# 1957  2.664405e+09  1.876341e+07   4282942.0  7314.05096  51.507401  48.3605
# 1962  2.899783e+09  2.042101e+07   4686039.5  7612.51336  53.609249  50.8810
# 1967  3.217478e+09  2.265830e+07   5170175.5  7906.31712  55.678290  53.8250
# 1972  3.576977e+09  2.518998e+07   5877996.5  8185.92888  57.647386  56.5300
# 1977  3.930046e+09  2.767638e+07   6404036.5  8458.96236  59.570157  59.6720
# 1982  4.289437e+09  3.020730e+07   7007320.0  8737.71400  61.533197  62.4415
# 1987  4.691477e+09  3.303857e+07   7774861.5  8976.19100  63.212613  65.8340
# 1992  5.110710e+09  3.599092e+07   8688686.5  9110.76800  64.160338  67.7030
# 1997  5.515204e+09  3.883947e+07   9735063.5  9232.08400  65.014676  69.3940
# ...

# %%
print("Se toman datos desde 1952 hasta 2007, sobre paises, cantidad de poblacion, esperanza de vida y PIB percapita. De la forma que esta dispuesta la infromacion es dificl analizar, ademas considerando que existe una gran cantidad de datos.")
# Out:
# Se toman datos desde 1952 hasta 2007, sobre paises, cantidad de poblacion, esperanza de vida y PIB percapita. De la forma que esta dispuesta la infromacion es dificl analizar, ademas considerando que existe una gran cantidad de datos.

# %%
print("Respecto a la: cantidad de problacion, especativa de vida al PIB percapita, este va aumentando con el paso del tiempo.")
# Out:
# Respecto a la: cantidad de problacion, especativa de vida al PIB percapita, este va aumentando con el paso del tiempo.

# %%
print("Al inicio de la toma de datos, se puede identificar que la mediana es menor al promedio, por lo tanto los valores estan distribuidos hacia la izquerda. Sin embargo al finalizar la toma de datos se revierte, quedando la mediana mayor al promedio, por lo que la distribucion pasa a estar a la derecha. ")
# Out:
# Al inicio de la toma de datos, se puede identificar que la mediana es menor al promedio, por lo tanto los valores estan distribuidos hacia la izquerda. Sin embargo al finalizar la toma de datos se revierte, quedando la mediana mayor al promedio, por lo que la distribucion pasa a estar a la derecha.

# %% [markdown]
# 4. ¿Sabías que en 1967 en Chile se inaugura el Aeropuerto Internacional Arturo Merino Benítez? Usando estos datos se puede especificar un año y obtener un marco de datos más pequeño para el año usando la función get_group(). Por ejemplo, podemos obtener el marco de datos agrupados para el año 1967. Comenta tus resultados. Escoge otro año explicando el porqué de la elección y qué resultados obtuviste.

# %%
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year", "continent", "country"], as_index=True).mean()
print(gapminder_grouped)
round(gapminder_grouped.loc[1967, "Americas", "Chile"],2)
# Out:
#                                       pop  lifeExp     gdpPercap
# year continent country
# 1952 Africa    Algeria          9279525.0   43.077   2449.008185
#                Angola           4232095.0   30.015   3520.610273
#                Benin            1738315.0   38.223   1062.752200
#                Botswana          442308.0   47.622    851.241141
#                Burkina Faso     4469979.0   31.975    543.255241
# ...                                   ...      ...           ...
# 2007 Europe    Switzerland      7554661.0   81.701  37506.419070
#                Turkey          71158647.0   71.777   8458.276384
#                United Kingdom  60776238.0   79.425  33203.261280
#      Oceania   Australia       20434176.0   81.235  34435.367440
#                New Zealand      4115771.0   80.204  25185.009110
#
# [1704 rows x 3 columns]
# pop          8858908.00
# lifeExp           60.52
# gdpPercap       5106.65
# Name: (1967, Americas, Chile), dtype: float64

# %%
print("Los resultados para Chile en 1967 de la poblacion es de: 8.858.908 personas, para la expectativa de vida es de: 60 años y del PIB percapita es de 5.106.")
# Out:
# Los resultados para Chile en 1967 de la poblacion es de: 8.858.908 personas, para la expectativa de vida es de: 60 años y del PIB percapita es de 5.106.

# %%
gapminder = pd.read_csv(gapminder_csv_url)
gapminder_grouped = gapminder.groupby(["year", "continent", "country"], as_index=True).mean()
print(gapminder_grouped)
round(gapminder_grouped.loc[1952, "Americas", "Chile"],2)
# Out:
#                                       pop  lifeExp     gdpPercap
# year continent country
# 1952 Africa    Algeria          9279525.0   43.077   2449.008185
#                Angola           4232095.0   30.015   3520.610273
#                Benin            1738315.0   38.223   1062.752200
#                Botswana          442308.0   47.622    851.241141
#                Burkina Faso     4469979.0   31.975    543.255241
# ...                                   ...      ...           ...
# 2007 Europe    Switzerland      7554661.0   81.701  37506.419070
#                Turkey          71158647.0   71.777   8458.276384
#                United Kingdom  60776238.0   79.425  33203.261280
#      Oceania   Australia       20434176.0   81.235  34435.367440
#                New Zealand      4115771.0   80.204  25185.009110
#
# [1704 rows x 3 columns]
# pop          6377619.00
# lifeExp           54.74
# gdpPercap       3939.98
# Name: (1952, Americas, Chile), dtype: float64

# %%
print("Los resultados para Chile en 1952 de la poblacion es de: 6.377.619 personas, para la expectativa de vida es de: 54 años y del PIB percapita es de 3.939.")
# Out:
# Los resultados para Chile en 1952 de la poblacion es de: 6.377.619 personas, para la expectativa de vida es de: 54 años y del PIB percapita es de 3.939.

# %%
print("Al comparar los resultados desde el inicio de la toma de datos, se obtien que todos los indicadores aumentaron.")
# Out:
# Al comparar los resultados desde el inicio de la toma de datos, se obtien que todos los indicadores aumentaron.

# %% [markdown]
# Ahora con los datos anteriores construya tablas pivote según las siguientes instrucciones:
# 1. Construya una tabla fijando “continent”, con las funciones vistas en clase

# %%
#Importar
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

gapminder = pd.read_csv(gapminder_csv_url)
gapminder .drop(['country' ,'year'],inplace=True,axis=1)
table = pd.pivot_table(data=gapminder,index=["continent"])
table
# Out:
#               gdpPercap    lifeExp           pop
# continent
# Africa      2193.754578  48.865330  9.916003e+06
# Americas    7136.110356  64.658737  2.450479e+07
# Asia        7902.150428  60.064903  7.703872e+07
# Europe     14469.475533  71.903686  1.716976e+07
# Oceania    18621.609223  74.326208  8.874672e+06

# %%
rounded_table = np.round(table,2)

# %% [markdown]
# 2. Realice una tabla de doble entrada, fijando “continent” y “year”.
# Comente sus resultados.

# %% [markdown]
# 3. Con las variables anteriores, obtenga el promedio de la variable “pop”.

# %%
table_pop = np.round(pd.pivot_table(data=gapminder, index="year",columns = "continent", aggfunc = {"pop" : np.mean}), 0)
table_pop
# Out:
#                   pop
# continent      Africa    Americas         Asia      Europe     Oceania
# year
# 1952        4570010.0  13806098.0   42283556.0  13937362.0   5343003.0
# 1957        5093033.0  15478157.0   47356988.0  14596345.0   5970988.0
# 1962        5702247.0  17330810.0   51404763.0  15345172.0   6641759.0
# 1967        6447875.0  19229865.0   57747361.0  16039299.0   7300207.0
# 1972        7305376.0  21175368.0   65180977.0  16687835.0   8053050.0
# 1977        8328097.0  23122708.0   72257987.0  17238818.0   8619500.0
# 1982        9602857.0  25211637.0   79095018.0  17708897.0   9197425.0
# 1987       11054502.0  27310159.0   87006690.0  18103139.0   9787208.0
# 1992       12674645.0  29570964.0   94948248.0  18604760.0  10459826.0
# 1997       14304480.0  31876016.0  102523803.0  18964805.0  11120715.0
# 2002       16033152.0  33990910.0  109145521.0  19274129.0  11727414.0
# 2007       17875763.0  35954847.0  115513752.0  19536618.0  12274974.0

# %% [markdown]
# 4. Obtenga un gráfico de barras del punto 3, comente sus resultados.

# %%
table_pop.plot(kind="bar");

# %%
ax = table_pop.T.plot(kind="bar", xlabel = "Continente", ylabel= "Población")

# %%
print("Respecto a los continentes en el tiempo, se puede visualizar que el valor de la poblacion fue aumentando. Donde se destaca el crecimiento en proporcion del continente de Asia, por sobre los demas.")
# Out:
# Respecto a los continentes en el tiempo, se puede visualizar que el valor de la poblacion fue aumentando. Donde se destaca el crecimiento en proporcion del continente de Asia, por sobre los demas.
